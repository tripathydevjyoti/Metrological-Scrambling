# %%
import numpy as np
import matplotlib.pyplot as plt

from qutip import (
    basis,
    tensor,
    sigmax,
    sigmaz,
    sigmay,
    qeye,
    ptrace,
    Qobj,
)

from scipy.linalg import lu_factor, lu_solve
from scipy.sparse import csc_matrix
from scipy.sparse.linalg import eigsh
from scipy.integrate import cumulative_trapezoid

import plotly.graph_objects as go
from mpl_toolkits.mplot3d import Axes3D

# %% [markdown]
# ## Crank-Nicolson Evolution

# %%
# ============================================================
# Core linear-algebra / dynamics utilities
# ============================================================

def crank_nicolson_propagator(H: Qobj, t: float, steps: int = 100) -> Qobj:
    """
    Crank–Nicolson approximation to U(t) = exp(-i H t).
    """
    dt = t / steps
    dim = H.shape[0]
    I = np.eye(dim, dtype=complex)

    A = I - 1j * (dt / 2) * H.full()
    B = I + 1j * (dt / 2) * H.full()

    lu, piv = lu_factor(A)
    U_step = lu_solve((lu, piv), B)
    U_total = np.linalg.matrix_power(U_step, steps)

    return Qobj(U_total, dims=H.dims)

# %% [markdown]
# ## Constructing the Hamiltonian

# %%
def spin_chain_ham(h: float, g: float, J: float, J2: float, N: int) -> Qobj:
    """
    Spin-chain Hamiltonian used throughout the notebook:
      H = -J Σ σ^z_i σ^z_{i+1} + J2 Σ σ^z_i σ^z_{i+2} - h Σ σ^x_i - g Σ σ^z_i
    """
    sx = [tensor([sigmax() if i == j else qeye(2) for i in range(N)]) for j in range(N)]
    sz = [tensor([sigmaz() if i == j else qeye(2) for i in range(N)]) for j in range(N)]

    H = (
        sum(-J * sz[i] * sz[i + 1] for i in range(N - 1))
        + sum(J2 * sz[i] * sz[i + 2] for i in range(N - 2))
        - sum(h * sx[i] for i in range(N))
        - sum(g * sz[i] for i in range(N))
    )
    return H


def ground_state_ket(H: Qobj) -> Qobj:
    """
    Ground state ket via sparse eigensolver (smallest algebraic eigenvalue).
    """
    Hs = csc_matrix(H.full())
    evals, evecs = eigsh(Hs, k=1, which="SA")
    N = len(H.dims[0])
    psi = Qobj(evecs[:, 0], dims=[H.dims[0], [1] * N])
    return psi.unit()

# %% [markdown]
# ## Loschmidt Echo Rate

# %%
def loschmidt_rate_function(
    *,
    N: int,
    J: float,
    J2: float, 
    g0: float,
    g1: float,
    tlist: np.ndarray,
    steps: int,
    eps: float = 1e-300,
    h0_quench: float,
    hf_quench: float,
) -> tuple[np.ndarray, np.ndarray]:
    """
    Loschmidt amplitude:
        G(t) = <psi0| e^{-i Hf t} |psi0>
    Rate function:
        r(t) = -(1/N) ln |G(t)|^2
    """
    H0 = spin_chain_ham(h=h0_quench, g=g0, J=J, J2=J2, N=N)
    Hf = spin_chain_ham(h=hf_quench, g=g1, J=J, J2=J2, N=N)

    psi0 = ground_state_ket(H0)

    G = np.empty(len(tlist), dtype=complex)
    rate = np.empty(len(tlist), dtype=float)

    for k, t in enumerate(tlist):
        Uf = crank_nicolson_propagator(Hf, t, steps=steps)
        psi_t = Uf * psi0

        overlap = psi0.dag() * psi_t
        amp = overlap if isinstance(overlap, complex) else overlap.full()[0, 0]
        G[k] = amp

        prob = max(abs(amp) ** 2, eps)
        rate[k] = -(1.0 / N) * np.log(prob)

    return G, rate


def plot_loschmidt_rate_and_derivative(tlist: np.ndarray, rate: np.ndarray) -> None:
    plt.figure(figsize=(7, 5))
    plt.plot(tlist, rate, lw=2)
    plt.xlabel("Time t")
    plt.ylabel(r"Rate function $r(t) = -\frac{1}{N}\ln |G(t)|^2$")
    plt.title("Loschmidt Rate Function vs Time")
    plt.grid(True)
    plt.tight_layout()
    #plt.savefig("I(t) J=1.0, hi=1.5, hf=0.2, g=0.4,.pdf")
    plt.show()

    drdt = np.gradient(rate, tlist)
    plt.figure(figsize=(7, 5))
    plt.plot(tlist, drdt, lw=2)
    plt.xlabel("Time t")
    plt.ylabel(r"$\partial_t r(t)$")
    plt.title("Time derivative of rate function")
    plt.grid(True)
    plt.tight_layout()
    plt.show()

# %% [markdown]
# ## Parameters and Plotting Rate function

# %%
N_los = 8
J_los = 1.0
J2_los = 0.0
g0 = 0.0 # g remains the same
g1 = 0.0

h0 = 1.5 #transverse field h is quenched across the critical point of h_c = 1.0
hf = 0.2

tlist_los = np.linspace(0.0, 10.0, 200)

G_amp, r_t = loschmidt_rate_function(
    N=N_los,
    J=J_los,
    J2=J2_los,
    g0=g0,
    g1=g1,
    tlist=tlist_los,
    steps=800,
    h0_quench = h0,
    hf_quench = hf
)

plot_loschmidt_rate_and_derivative(tlist_los, r_t)

# %% [markdown]
# ## Subsystem Quantum Fisher Information

# %%
def compute_time_qfi_spectral(states: list[Qobj], tlist: np.ndarray, subsystem_index: int = 0) -> np.ndarray:
    """
    Computes subsystem time-QFI using:
      - reduced density matrix rho_A(t) = Tr_{rest}[rho(t)]
      - finite-difference derivative drho_A/dt
      - spectral sum:
          F_Q(t) = sum_{m,n} 2/(p_m+p_n) | <m| drho/dt |n> |^2
    """
    qfi_list = []

    for i in range(len(tlist)):
        rho_A = ptrace(states[i], [subsystem_index])

        # finite difference drho/dt
        if i == 0:
            rho_A_next = ptrace(states[i + 1], [subsystem_index])
            dt = tlist[i + 1] - tlist[i]
            drho_dt = (rho_A_next - rho_A) / dt
        elif i == len(tlist) - 1:
            rho_A_prev = ptrace(states[i - 1], [subsystem_index])
            dt = tlist[i] - tlist[i - 1]
            drho_dt = (rho_A - rho_A_prev) / dt
        else:
            rho_A_next = ptrace(states[i + 1], [subsystem_index])
            rho_A_prev = ptrace(states[i - 1], [subsystem_index])
            dt = tlist[i + 1] - tlist[i - 1]
            drho_dt = (rho_A_next - rho_A_prev) / dt

        evals, evecs = rho_A.eigenstates()
        qfi_t = 0.0

        for m in range(len(evals)):
            for n in range(len(evals)):
                pm, pn = evals[m], evals[n]
                if pm + pn > 1e-12:
                    d_mn = complex(evecs[m].dag() * drho_dt * evecs[n])  # Qobj 1x1 -> complex
                    qfi_t += (2.0 / (pm + pn)) * abs(d_mn) ** 2

        qfi_list.append(np.real(qfi_t))

    return np.array(qfi_list)


def run_simulation_for_h(
    *,
    h_value: float,
    N: int,
    J: float,
    J2: float,
    g: float,
    tlist: np.ndarray,
    steps: int,
    subsystem_index: int = 0,
) -> tuple[np.ndarray, np.ndarray]:
    """
    For a given h:
      - prepares an initial state from H(h0=0, g)
      - evolves under H(h, g)
      - returns (subsystem QFI vs t, subsystem purity vs t)
    """
    print(f"Running simulation for h = {h_value}")

    #h_value0 = 1.5
    H_full = spin_chain_ham(h=h_value, g=g, J=J, J2=J2, N=N)
    #H_init_full = spin_chain_ham(h=h_value0, g=g, J=J, J2=J2, N=N)

    H_sparse_full = csc_matrix(H_full.full())
    E_full, psi_full = eigsh(H_sparse_full, k=1, which="SA")
    psi0_full = Qobj(psi_full[:, 0], dims=[H_full.dims[0], [1] * N])

    rho0 = psi0_full * psi0_full.dag()
    #O = tensor(sigmax(), *[qeye(2) for i in range(N-1)])
    O = tensor([sigmax()] + [qeye(2) for _ in range(N-1)])


    initial_state = O * rho0 * O.dag()

    states = []
    purity_t = []

    for t in tlist:
        U_full = crank_nicolson_propagator(H_full, t, steps)

        evolved_state = U_full * initial_state * U_full.dag()
        states.append(evolved_state)

        rho_A = ptrace(evolved_state, [subsystem_index])
        purity_t.append(np.real((rho_A * rho_A).tr()))

    purity_h = np.array(purity_t)
    qfi_vals = compute_time_qfi_spectral(states, tlist, subsystem_index=subsystem_index)

    return qfi_vals, purity_h


# ============================================================
# Post-processing: F(h,t), G(h,t), D(h,t) and plotting
# ============================================================
def compute_F_from_qfi(qfi_results: dict[float, np.ndarray], tlist: np.ndarray, h_list: np.ndarray) -> np.ndarray:
    """
    F(h,t) = Z(t)^2 / (8 t), where Z(t) = ∫_0^t sqrt(QFI(s)) ds
    """
    F_results = {}

    for h in h_list:
        qfi_t = np.array(qfi_results[h], dtype=float)
        qfi_t[qfi_t < 0] = 0.0

        sqrt_qfi = np.sqrt(qfi_t)
        Z_t = cumulative_trapezoid(sqrt_qfi, tlist, initial=0)

        F_t = np.zeros_like(Z_t)
        F_t[1:] = (Z_t[1:] ** 2) / (8 * tlist[1:])

        F_results[h] = F_t

    F_matrix = np.array([F_results[h] for h in h_list])
    return F_matrix


def compute_G_from_purity(purity_results: dict[float, np.ndarray], tlist: np.ndarray, h_list: np.ndarray) -> np.ndarray:
    """
    G(h,t) = - ln(purity(t)) / t
    """
    G_results = {}

    for h in h_list:
        purity_t = np.array(purity_results[h], dtype=float)
        purity_t[purity_t <= 0] = 1e-12

        G_t = np.zeros_like(purity_t)
        G_t[1:] = -np.log(purity_t[1:]) / tlist[1:]

        G_results[h] = G_t

    G_matrix = np.array([G_results[h] for h in h_list])
    return G_matrix

# %%
def plot_surface_plotly(
    *,
    h_list: np.ndarray,
    tlist: np.ndarray,
    Z_matrix: np.ndarray,
    title: str,
    xlab: str = "h",
    ylab: str = "t",
    zlab: str = "value",
    colorscale: str = "Viridis",
    width: int = 950,
    height: int = 750,
) -> None:
    fig = go.Figure(
        data=[
            go.Surface(
                x=h_list,
                y=tlist,
                z=Z_matrix.T,
                colorscale=colorscale,
                showscale=True,
            )
        ]
    )
    fig.update_layout(
        title=title,
        scene=dict(xaxis_title=xlab, yaxis_title=ylab, zaxis_title=zlab),
        width=width,
        height=height,
    )
    fig.show()


def plot_surface_matplotlib(
    *,
    h_list: np.ndarray,
    tlist: np.ndarray,
    Z_matrix: np.ndarray,
    title: str,
    zlabel: str,
) -> None:
    fig = plt.figure(figsize=(9, 7))
    ax = fig.add_subplot(111, projection="3d")

    H, T = np.meshgrid(h_list, tlist)
    ax.plot_surface(H, T, Z_matrix.T, cmap="viridis", linewidth=0, antialiased=True)

    ax.set_title(title)
    ax.set_xlabel("h")
    ax.set_ylabel("t")
    ax.set_zlabel(zlabel)
    plt.tight_layout()
    plt.show()


def plot_qfi_contour(h_list: np.ndarray, tlist: np.ndarray, QFI_matrix: np.ndarray, save_path: str | None = None) -> None:
    plt.figure(figsize=(8, 6))

    plt.contour(
        h_list,
        tlist,
        QFI_matrix.T,
        levels=[0],
        colors="black",
        linewidths=2,
    )

    plt.contourf(
        h_list,
        tlist,
        QFI_matrix.T,
        levels=50,
        cmap="coolwarm",
    )

    plt.colorbar(label="subsystem QFI ")
    plt.xlabel("h (Transverse Field)")
    plt.ylabel("t (Time) (estimation parameter)")

    if save_path is not None:
        plt.savefig(save_path)

    plt.tight_layout()
    plt.show()


def plot_purity_vs_time(h_list: np.ndarray, tlist: np.ndarray, purity_results: dict[float, np.ndarray]) -> None:
    plt.figure(figsize=(8, 6))
    for h in h_list:
        plt.plot(tlist, purity_results[h], label=f"h={h:.2f}")

    plt.xlabel("Time t")
    plt.ylabel("Purity  γ(t) = Tr[ρ_A²]")
    plt.title("Subsystem Purity vs Time for different h values")
    plt.legend()
    plt.grid(True)
    plt.tight_layout()
    plt.show()


def plot_D_contour(h_list: np.ndarray, tlist: np.ndarray, D_matrix: np.ndarray) -> None:
    plt.figure(figsize=(8, 6))

    plt.contour(
        h_list,
        tlist,
        D_matrix.T,
        levels=[1],
        colors="black",
        linewidths=2,
    )

    plt.contourf(
        h_list,
        tlist,
        D_matrix.T,
        levels=50,
        cmap="coolwarm",
    )

    plt.colorbar(label="D(h,t) = G(h,t) - F(h,t)")
    plt.xlabel("h (Transverse Field)")
    plt.ylabel("t (Time) (estimation parameter)")
    plt.title("Contour of D(h,t) with D=1 curve highlighted")
    plt.tight_layout()
    plt.show()


def plot_combined_surfaces_plotly(
    *,
    h_list: np.ndarray,
    tlist: np.ndarray,
    G_matrix: np.ndarray,
    F_matrix: np.ndarray,
) -> None:
    fig = go.Figure()

    fig.add_trace(
        go.Surface(
            x=h_list,
            y=tlist,
            z=G_matrix.T,
            colorscale="Inferno",
            opacity=0.85,
            showscale=False,
            name="G(h,t) = -ln(purity)/t",
        )
    )

    fig.add_trace(
        go.Surface(
            x=h_list,
            y=tlist,
            z=F_matrix.T,
            colorscale="Cividis",
            opacity=0.55,
            showscale=True,
            name="F(h,t)",
        )
    )

    fig.update_layout(
        title="Overlay: G(h,t) and F(h,t)",
        scene=dict(
            xaxis_title="h",
            yaxis_title="t",
            zaxis_title="value",
        ),
        width=1000,
        height=800,
    )

    fig.show()

# %% [markdown]
# ## Parameters for subsystem QFI

# %%
N = 8
J = 1.0
J2 = 0.0
g = 0.0

h_list = np.linspace(-4.0, 4.0, 20)
tlist = np.linspace(0.0, 1.0, 500)
steps = 800

qfi_results = {}
purity_results = {}

for hv in h_list:
    qfi_results[hv], purity_results[hv] = run_simulation_for_h(
        h_value=hv,
        N=N,
        J=J,
        J2=J2,
        g=g,
        tlist=tlist,
        steps=steps,
        subsystem_index=0,
    )

QFI_matrix = np.array([qfi_results[hv] for hv in h_list])
# Out:
# Running simulation for h = -4.0
# Running simulation for h = -3.5789473684210527
# Running simulation for h = -3.1578947368421053
# Running simulation for h = -2.736842105263158
# Running simulation for h = -2.3157894736842106
# Running simulation for h = -1.8947368421052633
# Running simulation for h = -1.473684210526316
# Running simulation for h = -1.0526315789473686
# Running simulation for h = -0.6315789473684212
# Running simulation for h = -0.2105263157894739
# Running simulation for h = 0.21052631578947345
# Running simulation for h = 0.6315789473684212
# Running simulation for h = 1.0526315789473681
# Running simulation for h = 1.473684210526315
# Running simulation for h = 1.8947368421052628
# Running simulation for h = 2.3157894736842106
# Running simulation for h = 2.7368421052631575
# Running simulation for h = 3.1578947368421044
# Running simulation for h = 3.578947368421052
# Running simulation for h = 4.0

# %%
def plot_surface_plotly(
    *,
    h_list: np.ndarray,
    tlist: np.ndarray,
    Z_matrix: np.ndarray,
    title: str,
    xlab: str,
    ylab: str,
    zlab: str,
    colorscale: str = "Viridis",
    width: int = 900,
    height: int = 700,
):
    fig = go.Figure(
        data=[
            go.Surface(
                x=h_list,
                y=tlist,
                z=Z_matrix.T,
                colorscale=colorscale,
                showscale=True,
            )
        ]
    )

    fig.update_layout(
        title=title,
        scene=dict(
            xaxis_title=xlab,
            yaxis_title=ylab,
            zaxis_title=zlab,
        ),
        width=width,
        height=height,
    )

    fig.show()

# %% [markdown]
# ## Plotting the subsystem QFI

# %% [markdown]
# Here, we plot the susbsytem QFI for the integrable Ising chain with $g=0.0$. You can plot the subsystem QFI for the non-integrable Ising chain by setting a non-zero transverse field $g\neq 0$ above in the code block named : "Parameters for subsystem QFI". We find that at time $t=0$, the subsystem QFI for the integrable case doesnot show any peaks i.e no signs of a phase transition, rather its flattened out around $h=0$. On the other hand, in the presence of a transverse field, one finds clear peaks symmetric around $h=0$. The reason is still being investigated.

# %%
# Plotly interactive QFI surface (matches notebook component)
plot_surface_plotly(
    h_list=h_list,
    tlist=tlist,
    Z_matrix=QFI_matrix,
    title="Interactive 3D QFI(h, t)",
    xlab="h",
    ylab="Time t (estimation parameter)",
    zlab="QFI",
    colorscale="Viridis",
    width=950,
    height=750,
)

# Contour plot of QFI (matches notebook component)
#plot_qfi_contour(h_list, tlist, QFI_matrix) #save_path="tfim_nnn_qfi_contour.pdf")

# Purity vs time (matches notebook component)
#plot_purity_vs_time(h_list, tlist, purity_results)

# Build F and G matrices (matches notebook components)
#F_matrix = compute_F_from_qfi(qfi_results, tlist, h_list)
#G_matrix = compute_G_from_purity(purity_results, tlist, h_list)

"""
# Plotly interactive 3D plot of F (matches notebook component)
plot_surface_plotly(
    h_list=h_list,
    tlist=tlist,
    Z_matrix=F_matrix,
    title=r"Interactive 3D Plot of  $F(h,t)=\dfrac{Z(t)^2}{8t}$",
    xlab="h (Transverse Field)",
    ylab="t (Time) (estimation parameter)",
    zlab=r"$Z(t)^2/8t$",
    colorscale="Viridis",
    width=950,
    height=750,
)
"""
"""
# Plotly interactive 3D plot of G (matches notebook component)
plot_surface_plotly(
    h_list=h_list,
    tlist=tlist,
    Z_matrix=G_matrix,
    title=r"Interactive 3D Surface of  $-\ln(\mathrm{purity}) / t$",
    xlab="h (transverse field)",
    ylab="t (time)",
    zlab=r"$-\ln(\gamma)/t$",
    colorscale="Turbo",
    width=900,
    height=700,
)

# Matplotlib 3D surface of G (matches notebook component)
plot_surface_matplotlib(
    h_list=h_list,
    tlist=tlist,
    Z_matrix=G_matrix,
    title="3D Surface: -ln(purity)/t",
    zlabel=r"$-\ln(\gamma)/t$",
)

# Overlay G and F as two surfaces (matches notebook component)
plot_combined_surfaces_plotly(
    h_list=h_list,
    tlist=tlist,
    G_matrix=G_matrix,
    F_matrix=F_matrix,
)

# D(h,t) contour (matches notebook component)
D_matrix = G_matrix - F_matrix
plot_D_contour(h_list, tlist, D_matrix)
"""
# Out:
# <div>                            <div id="26dfd1b3-a1ab-452d-840d-67e6a437a409" class="plotly-graph-div" style="height:750px; width:950px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("26dfd1b3-a1ab-452d-840d-67e6a437a409")) {                    Plotly.newPlot(                        "26dfd1b3-a1ab-452d-840d-67e6a437a409",                        [{"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"showscale":true,"x":[-4.0,-3.5789473684210527,-3.1578947368421053,-2.736842105263158,-2.3157894736842106,-1.8947368421052633,-1.473684210526316,-1.0526315789473686,-0.63
# ...
